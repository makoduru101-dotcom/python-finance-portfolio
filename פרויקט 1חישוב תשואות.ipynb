# %%
# prices של מניה
prices = [100, 105, 110, 120]

# מחיר התחלה
start = prices[0]

# מחיר סיום
end = prices[-1]

# חישוב תשואה
returns = (end - start) / start

print("Return:", returns)
# Out:
# Return: 0.2

# %%
def caculate_return(prices):
    start = prices[0]
    end = prices [-1]
    result = (end-start)/ start
    return result

print(caculate_return([100,105,110,120]))
# Out:
# 0.2

# %%
def caculate_return(prices):
    start = prices[0]
    end=prices[-1]
    result=(end-start)/start
    print("Start:",start)
    print("End:",end)
    return result
output=caculate_return([100,105,110,120])
print("Return",output)
# Out:
# Start: 100
# End: 120
# Return 0.2
